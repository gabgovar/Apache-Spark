# %% [markdown]
# <a href="https://colab.research.google.com/github/gabgovar/Apache-Spark/blob/main/Spark_Streaming_with_RDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spark Streaming

# %% [markdown]
# ## Instalando as Demendências do Hadoop Spark no Google Colab

# %%
# instalar as dependências
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
# !pip install -q findspark

# %% [markdown]
# ## Configurando as Demendências do Hadoop Spark no Google Colab

# %%
# configurar as variáveis de ambiente
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

# tornar o pyspark "importável"
import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')
findspark.find()
# Out:
# 'spark-2.4.4-bin-hadoop2.7/python/pyspark'

# %% [markdown]
# ## Spark Streamin with RDD

# %%
from pyspark.streaming import StreamingContext
from pyspark import SparkConf, SparkContext


conf = SparkConf().setAppName("Streaming")
sc = SparkContext.getOrCreate(conf=conf)

ssc = StreamingContext(sc,1)

# %%
rdd = ssc.textFileStream("/content/drive/MyDrive/PySpark/data/data_test")

# %%
rdd = rdd.map(lambda x: (x,1))
rdd = rdd.reduceByKey(lambda x,y: x+y)


rdd.pprint()
ssc.start()
ssc.awaitTerminationOrTimeout(100)
# Out:
# -------------------------------------------
# Time: 2022-02-03 12:28:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-02-03 12:28:46
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-02-03 12:28:47
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-02-03 12:28:48
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-02-03 12:28:49
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-02-03 12:28:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-02-03 12:28:51
# -------------------------------------------
#
# -------------------------------------------
# Time: 2022-02-03 12:28:52
# -------------------------------------------
#
# ...

# %%
ssc.stop()
